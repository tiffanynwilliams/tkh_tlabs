# %% [markdown]
# # Full Beginner Practice Notebook (Problems Only)

# %% [markdown]
# ## Part 1: OOP (Mixed Concepts)

# %% [markdown]
# ### Problem 1: Animal Sounds 🐶🐱
#
# Create a base class `Animal` with method `speak()`.
#
# Then:
# - Create `Dog` class → returns "bark"
# - Create `Cat` class → returns "meow"
#
# (Practice inheritance + overriding)

# %%
# your code

# %% [markdown]
# ### Problem 2: Player Scores 🎮
#
# Create class `Player`:
# - stores name and score
#
# Create:
# - method `add_points(x)`
# - method `get_score()`
#
# Create 2 players and update scores.

# %%
# your code

# %% [markdown]
# ### Problem 3: Shape Areas 🔺⬛
#
# Base class `Shape`
#
# Create:
# - `Square(side)` → area = side²
# - `Rectangle(w,h)` → area = w*h
#
# (Use overriding)

# %%
# your code

# %% [markdown]
# ### Problem 4: Bank Account with Fees 💰
#
# Create class `Account`:
# - balance
#
# Create subclass `PremiumAccount`:
# - withdraw has NO fee
#
# Normal account:
# - withdraw subtracts $1 fee
#
# (Use inheritance + method override)

# %%
# your code

# %% [markdown]
# ## Part 2: Pandas (Beginner → Groupby)

# %% [markdown]
# Dataset:
#
# user: [1..8]
# group: ["A","A","B","B","A","B","A","B"]
# clicked: [1,0,1,1,0,1,1,0]
#
# Tasks:
# 1. Create DataFrame
# 2. avg click for A
# 3. avg click for B
# 4. difference
# 5. count per group
# 6. groupby: avg clicks per group

# %%
# your work

# %% [markdown]
# ## Part 3: Hypothesis Setup

# %% [markdown]
# ### Scenario 1: Button Click
#
# Old: 20%
# New: 25%
#
# Write:
# H0
# H1
# Type I
# Type II

# %% [markdown]
# ### Scenario 2: Email Opens
#
# Old: 30%
# New: 28%
#
# Write:
# H0
# H1
# Is this one-sided or two-sided?

# %% [markdown]
# ### Scenario 3: Game Win Rate
#
# Old: 50%
# New: 60%
#
# Define:
# Power
# What increases power?

# %% [markdown]
# ## Part 4: Simulation Problem 🎲

# %% [markdown]
# Simulate an experiment:
#
# - true A = 0.4
# - true B = 0.5
#
# Tasks:
# 1. simulate 100 users each
# 2. check if B > A
# 3. repeat 500 times
# 4. compute how often B wins

# %%
# your simulation
