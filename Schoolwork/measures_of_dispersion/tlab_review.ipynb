# %% [markdown]
# ## TLAB Review
#
# Let's go over concepts from this weeks TLAB.

# %%
# watch the code from early on W4D3 to fill in the rest of teh code (specifically the module1)
import statistics as stats
data = []

# open file using file I/O and read it into the `data` list
file_object = open("phase0.txt")
file_data = file_object.readlines()

def clean_heartrate_data(clean_data):
    TO_REMOVE_NEWLINE = '\n'
    TO_REMOVE_NODATA = 'NO DATA\n'
    cleaned_data = []

    # clean each object by looping through the data
    for row in data:
        if row != TO_REMOVE_NEWLINE and row != TO_REMOVE_NODATA:
            new_row = int(row)
            cleaned_data.append(new_row)

    # calculate the average of each data file

    mean = round(stats.mean(cleaned_data), 1)
   

    return(cleaned_data)

clean_data = clean_heartrate_data(data)
# Out:
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# Cell In[42], line 26
#      21     mean = round(stats.mean(cleaned_data), 1)
#      24     return(cleaned_data)
# ---> 26 clean_data = clean_heartrate_data(data)
#
# Cell In[42], line 21, in clean_heartrate_data(clean_data)
#      17         cleaned_data.append(new_row)
#      19 # calculate the average of each data file
# ---> 21 mean = round(stats.mean(cleaned_data), 1)
#      24 return(cleaned_data)
#
# File c:\Users\Tiffany\anaconda3\envs\da\Lib\statistics.py:486, in mean(data)
#     484 T, total, n = _sum(data)
#     485 if n < 1:
# --> 486     raise StatisticsError('mean requires at least one data point')
#     487 return _convert(total / n, T)
#
# StatisticsError: mean requires at least one data point
