# %%
import pandas as pd

shopping_data = pd.read_csv("data/processed/shopping_cleaned.csv")

# %%
shopping_data.head()
# check the unique values if u know the key!
shopping_data['Season'].unique()
# Out:
# <StringArray>
# ['Winter', 'Summer', 'Fall', 'Spring']
# Length: 4, dtype: str

# %%
shopping_data.pivot_table(values='Purchase Amount (USD)', index='Gender',columns='Season', aggfunc= 'sum').reset_index().sort_values('Summer', ascending=False)
# Out:
# Season      Gender          Fall        Spring        Summer        Winter
# 0           Female  15184.111205   8656.842384  16096.794126  20539.445580
# 1             Male  18462.379075  10022.207509  13279.099197  19227.165684
# 2       Non-binary    307.472417    126.632303    267.022377    401.493276

# %%
# label code block section 
print("*"*9)
print("QUESTIONS")
print("*"*9)

# output the questions to be answered here
print("1) Which season yields the highest amount of purchases overall?\n"
      "3) What is the relationship between the customer ages and their frequency of purchases?\n"
      "5) Of the most popular sizes purchased overall, which has yields the highest reviews?\n"
      "6) How frequently is a promo code used by the customers with the highest frequency of purchases?")
# Out:
# *********
# QUESTIONS
# *********
# 1) Which season yields the highest amount of purchases overall?
# 3) What is the relationship between the customer ages and their frequency of purchases?
# 5) Of the most popular sizes purchased overall, which has yields the highest reviews?
# 6) How frequently is a promo code used by the customers with the highest frequency of purchases?

# %%
# question 1, investigate via pivot_table() method
